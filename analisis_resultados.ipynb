# %%
import pandas as pd

# %% [markdown]
# Lectura de los resultados

# %%
results = pd.read_csv('results1.csv')
results = results.drop(columns=['Unnamed: 0'])
ulutas_results = pd.read_csv('ulutas_results.csv')

# %% [markdown]
# Agregamos resultados

# %%
agg_results = results.groupby(["Problem"]).mean().reset_index() #agrego por problema y calculo media de eficacia, iteraciones y tiempo de ejecución
agg_results = agg_results.join(ulutas_results.set_index('Problem'), on = 'Problem') #hago join con fichero de resultados de ulutas
agg_results = agg_results[['Problem', 'Problem Code', 'Efficacy', 'Iterations', 'Elapsed Time', 'Ulutas Efficacy']] #me quedo con columnas que me interesan
agg_results['Efficacy Difference'] = round((agg_results['Ulutas Efficacy'] - agg_results['Efficacy'])*100/agg_results['Ulutas Efficacy'], 2) #calculo diferencia entre nuestra eficacia y la de Ulutas
agg_results
# Out:
#                                               Problem Problem Code  Efficacy  \
# 0                       10x10_Mosier_Taube(1985a).txt          A10  0.743621
# 1                   14x24_Askin_Subramanian(1987).txt          A12  0.671237
# 2                             14x24_Stanfel(1985).txt          A13  0.674723
# 3                         15x10_Chan_Milner(1982).txt          A11  0.920000
# 4                     16x24_McCormick_et_al(1972).txt          A14  0.484591
# 5                    16x30_Srinivasan_et_al(1990).txt          A15  0.613050
# 6                                16x43_King(1980).txt          A16  0.494034
# 7                              18x24_Carrie(1973).txt          A17  0.550931
# 8                       20x20_Mosier_Taube(1985b).txt          A18  0.412392
# 9                           20x35_Boe_Cheng(1991).txt          A21  0.542731
# 10              20x35_Carrie(1973)-Burbidge(1969).txt          A20  0.725911
# 11                        23x20_Kumar_et_al(1986).txt          A19  0.465739
# 12  24x40_Chandrasekharan_Rajagopalan(1989)[Datase...          A22  0.802840
# 13  24x40_Chandrasekharan_Rajagopalan(1989)[Datase...          A23  0.698960
# 14  24x40_Chandrasekharan_Rajagopalan(1989)[Datase...          A24  0.627019
# 15  24x40_Chandrasekharan_Rajagopalan(1989)[Datase...          A25  0.451381
# 16  24x40_Chandrasekharan_Rajagopalan(1989)[Datase...          A26  0.418349
# 17  24x40_Chandrasekharan_Rajagopalan(1989)[Datase...          A27  0.415218
# 18                          27x27_McCormick(1972).txt          A28  0.528435
# 19                             28x46_Carrie(1973).txt          A29  0.426764
# 20           30x41_Kumar_Vanelli(1987)[Figure-11].txt          A30  0.564788
# 21                  30x50_Stanfel(1985)[Figure-5].txt          A31  0.506643
# 22                  30x50_Stanfel(1985)[Figure-6].txt          A32  0.423425
# 23                    30x90_King_Nakornchai(1982).txt          A33  0.403310
# 24                         5x18_Seifoddini(1989b).txt           A3  0.795918
# 25           5x7_King_Nakornchai(1982)[Figure-1a].txt           A1  0.823529
# 26           5x7_Waghodekar_Sahu(1984)[Problem-2].txt           A2  0.695652
# 27                           6x8_Kusiak_Cho(1992).txt           A4  0.769231
# 28                   7x11_Boctor(1991)[Example-1].txt           A6  0.708333
# 29                         7x11_Kusiak_Chow(1987).txt           A5  0.608696
# 30                    8x12_Seifoddini_Wolfe(1986).txt           A7  0.690989
# 31        8x20_Chandrasekharan_Rajagopalan(1986a).txt           A8  0.852459
# 32        8x20_Chandrasekharan_Rajagopalan(1986b).txt           A9  0.585466
#
#     Iterations  Elapsed Time  Ulutas Efficacy  Efficacy Difference
# 0       1001.0    223.738417           0.7500                 0.85
# 1       2001.0    843.161949           0.7206                 6.85
# 2       2001.0    794.175548           0.7183                 6.07
# 3       1835.9    498.092919           0.9200                -0.00
# 4       2001.0    868.160499           0.5326                 9.01
# 5       2001.0   1010.036502           0.6899                11.14
# 6       2001.0   1289.465809           0.5753                14.13
# 7       4239.9   1558.060463           0.5773                 4.57
# 8       4038.8   1447.633210           0.4345                 5.09
# 9       4525.7   2357.252566           0.5798                 6.39
# 10      4464.1   2322.208443           0.7791                 6.83
# 11      4246.4   1704.665746           0.5081                 8.34
# 12      4501.0   3047.945508           1.0000                19.72
# 13      4687.3   3177.851637           0.8511                17.88
# 14      4900.7   3316.178741           0.7351                14.70
# 15      4978.1   3365.931714           0.5329                15.30
# 16      4966.7   3351.387322           0.4895                14.54
# 17      7098.0   6091.901138           0.4600                 9.74
# 18      4851.3   3557.097846           0.5482                 3.61
# 19      6714.5   7435.273742           0.4655                 8.32
# 20      6930.8   7480.280142           0.6264                 9.84
# 21      8138.9  10331.510690           0.5967                15.09
# 22      7982.6  10044.851166           0.5062                16.35
# 23      7442.5  15637.340446           0.4782                15.66
# 24      1339.3    244.441748           0.7959                -0.00
# 25      1039.1    148.289707           0.8235                -0.00
# 26      1049.8    148.731869           0.6957                 0.01
# 27      1073.1    167.098053           0.7692                -0.00
# 28      1500.6    271.978869           0.7083                -0.00
# 29      1840.4    331.477875           0.6087                 0.00
# 30      1737.7    344.648647           0.6944                 0.49
# 31      1973.8    482.933721           0.8525                 0.00
# 32      1810.7    443.129038           0.5872                 0.30
