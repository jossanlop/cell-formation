# %%
import pandas as pd

# %% [markdown]
# Lectura de los resultados

# %%
results = pd.read_csv('results_A1_16.csv')
results = results.drop(columns=['Unnamed: 0'])
ulutas_results = pd.read_csv('ulutas_results.csv')

# %% [markdown]
# Agregamos resultados

# %%
agg_results = results.groupby(["Problem"]).mean().reset_index() #agrego por problema y calculo media de eficacia, iteraciones y tiempo de ejecución
agg_results = agg_results.join(ulutas_results.set_index('Problem'), on = 'Problem') #hago join con fichero de resultados de ulutas
agg_results = agg_results[['Problem', 'Problem Code', 'Efficacy', 'Iterations', 'Elapsed Time', 'Ulutas Efficacy']] #me quedo con columnas que me interesan
agg_results['Efficacy Difference'] = round(agg_results['Ulutas Efficacy'] - agg_results['Efficacy'], 3) #calculo diferencia entre nuestra eficacia y la de Ulutas
agg_results
# Out:
#                                         Problem Problem Code  Efficacy  \
# 0                 10x10_Mosier_Taube(1985a).txt          A10  0.743621
# 1             14x24_Askin_Subramanian(1987).txt          A12  0.671237
# 2                       14x24_Stanfel(1985).txt          A13  0.674723
# 3                   15x10_Chan_Milner(1982).txt          A11  0.920000
# 4               16x24_McCormick_et_al(1972).txt          A14  0.484591
# 5              16x30_Srinivasan_et_al(1990).txt          A15  0.613050
# 6                          16x43_King(1980).txt          A16  0.494034
# 7                    5x18_Seifoddini(1989b).txt           A3  0.795918
# 8      5x7_King_Nakornchai(1982)[Figure-1a].txt           A1  0.823529
# 9      5x7_Waghodekar_Sahu(1984)[Problem-2].txt           A2  0.695652
# 10                     6x8_Kusiak_Cho(1992).txt           A4  0.769231
# 11             7x11_Boctor(1991)[Example-1].txt           A6  0.708333
# 12                   7x11_Kusiak_Chow(1987).txt           A5  0.608696
# 13              8x12_Seifoddini_Wolfe(1986).txt           A7  0.690989
# 14  8x20_Chandrasekharan_Rajagopalan(1986a).txt           A8  0.852459
# 15  8x20_Chandrasekharan_Rajagopalan(1986b).txt           A9  0.585466
#
#     Iterations  Elapsed Time  Ulutas Efficacy  Efficacy Difference
# 0       1001.0    223.738417           0.7500                0.006
# 1       2001.0    843.161949           0.7206                0.049
# 2       2001.0    794.175548           0.7183                0.044
# 3       1835.9    498.092919           0.9200               -0.000
# 4       2001.0    868.160499           0.5326                0.048
# 5       2001.0   1010.036502           0.6899                0.077
# 6       2001.0   1289.465809           0.5753                0.081
# 7       1339.3    244.441748           0.7959               -0.000
# 8       1039.1    148.289707           0.8235               -0.000
# 9       1049.8    148.731869           0.6957                0.000
# 10      1073.1    167.098053           0.7692               -0.000
# 11      1500.6    271.978869           0.7083               -0.000
# 12      1840.4    331.477875           0.6087                0.000
# 13      1737.7    344.648647           0.6944                0.003
# 14      1973.8    482.933721           0.8525                0.000
# 15      1810.7    443.129038           0.5872                0.002
